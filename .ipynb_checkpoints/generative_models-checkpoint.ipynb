# %%
# %matplotlib tk
# %autosave 180

import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
#from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
#from statsmodels import robust
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
import os

# run pca and visualize
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
from yass.config import Config
from yass.explore.explorers import RecordingExplorer

colors = [
'black','blue','red','green','cyan','magenta','brown','pink',
'orange','firebrick','lawngreen','dodgerblue','crimson','orchid','slateblue',
'darkgreen','darkorange','indianred','darkviolet','deepskyblue','greenyellow',
'peru','cadetblue','forestgreen','slategrey','lightsteelblue','rebeccapurple',
'darkmagenta','yellow','hotpink']
# Out:
# Autosaving every 180 seconds
# <style>.container { width:100% !important; }</style>

# %%
data_out = np.load('/media/cat/10TB/in_vivo/tim/alex/C1/spontaneous/Spontaneous_1iso_150Hz_10000fr_1_filtered.npy')
print (data_out.shape)
# Out:
# (10001, 128, 128)

# %%
data_out = (data-np.mean(data,axis=0))/data

# %%
plt.imshow(data_out[1000])
plt.show()

# %%
print (np.mean(data,axis=0).shape)
print (np.mean(data,axis=0))
# Out:
# (128, 128)
# [[ 69.76872313  71.42755724  73.38466153 ...  78.94840516  77.97930207
#    75.87881212]
#  [ 71.04249575  72.24147585  73.58424158 ...  79.54234577  78.81111889
#    78.10348965]
#  [ 74.11758824  74.8260174   76.71022898 ...  80.80881912  79.90860914
#    78.91720828]
#  ...
#  [137.55584442 146.24367563 153.3209679  ... 196.39536046 183.50414959
#   173.62623738]
#  [134.42355764 141.89521048 150.39146085 ... 181.52214779 173.40255974
#   165.36666333]
#  [132.25537446 138.90810919 146.55634437 ... 178.66163384 171.48435156
#   163.57434257]]

# %%
import matplotlib.animation as animation

global ctr

img_stack = data_out[1000:3000]
ctr=0

class make_vid(object):
    
    def __init__(self, img_stack):
    
        self.ctr = 0
        self.img_stack = img_stack
        n_frames = img_stack.shape[0]
        self.fig = plt.figure()
        vmin = np.nanmin(img_stack)*.25; 
        vmax=np.nanmax(img_stack)*.25
        self.im = plt.imshow(img_stack[0], animated=True, vmin=vmin, vmax=vmax)
        plt.title("Frame: 0", fontsize=20)

        ani = animation.FuncAnimation(self.fig, self.updatefig, frames = n_frames, interval=1, blit=True)
        writer = animation.writers['ffmpeg'](fps=30)
        ani.save('/home/cat/test3.mp4',writer=writer,dpi=100)

    def updatefig(self, *args):
        print (" frame: ", self.ctr, " / ", self.img_stack.shape[0])
        plt.title("Frame: "+str(self.ctr)+", sec: "+str(np.round(self.ctr/150.,2)))
        self.im.set_array(self.img_stack[self.ctr])
        self.ctr+=1
        return self.im,

make_vid(img_stack)
# Out:
#  frame:  0  /  2000
#  frame:  1  /  2000
#  frame:  2  /  2000
#  frame:  3  /  2000
#  frame:  4  /  2000
#  frame:  5  /  2000
#  frame:  6  /  2000
#  frame:  7  /  2000
#  frame:  8  /  2000
#  frame:  9  /  2000
#  frame:  10  /  2000
#  frame:  11  /  2000
#  frame:  12  /  2000
#  frame:  13  /  2000
#  frame:  14  /  2000
#  frame:  15  /  2000
#  frame:  16  /  2000
#  frame:  17  /  2000
#  frame:  18  /  2000
#  frame:  19  /  2000
#  frame:  20  /  2000
#  frame:  21  /  2000
#  frame:  22  /  2000
#  frame:  23  /  2000
#  frame:  24  /  2000
#  frame:  25  /  2000
#  frame:  26  /  2000
#  frame:  27  /  2000
#  frame:  28  /  2000
#  frame:  29  /  2000
#  frame:  30  /  2000
#  frame:  31  /  2000
#  frame:  32  /  2000
#  frame:  33  /  2000
#  frame:  34  /  2000
#  frame:  35  /  2000
#  frame:  36  /  2000
#  frame:  37  /  2000
#  frame:  38  /  2000
#  frame:  39  /  2000
#  frame:  40  /  2000
#  frame:  41  /  2000
#  frame:  42  /  2000
# ...
